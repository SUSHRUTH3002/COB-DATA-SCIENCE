# %%
import requests
import pandas as pd
api_url = "https://api.binance.com/api/v3/ticker/24hr"
response = requests.get(api_url)
if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)
    display(df.head())
    df.to_csv("binance_data.csv", index=False)
    print("CSV file created successfully.")
else:
    print(f"Error: {response.status_code}")
# Out:
#     symbol  priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0   ETHBTC  -0.00045000             -0.825       0.05434460     0.05454000
# 1   LTCBTC  -0.00001800             -0.839       0.00214372     0.00214700
# 2   BNBBTC  -0.00022400             -3.029       0.00728879     0.00739400
# 3   NEOBTC  -0.00000740             -3.146       0.00023039     0.00023530
# 4  QTUMETH   0.00002900              2.129       0.00137922     0.00136800
#
#     lastPrice      lastQty    bidPrice       bidQty    askPrice  ...  \
# 0  0.05408000   3.16180000  0.05408000  50.96490000  0.05409000  ...
# 1  0.00212800  13.44600000  0.00212800  92.74700000  0.00212900  ...
# 2  0.00717000   0.53700000  0.00716900  17.22200000  0.00717000  ...
# 3  0.00022780  29.13000000  0.00022780  31.40000000  0.00022790  ...
# 4  0.00139100  19.20000000  0.00138700  44.60000000  0.00139400  ...
#
#     openPrice   highPrice    lowPrice          volume    quoteVolume  \
# 0  0.05453000  0.05483000  0.05388000  40301.10550000  2190.14741229
# 1  0.00214600  0.00216000  0.00212100  31188.18600000    66.85873561
# 2  0.00739400  0.00741300  0.00715000  37254.78500000   271.54219124
# 3  0.00023520  0.00023560  0.00022650  33361.86000000     7.68632984
# 4  0.00136200  0.00140000  0.00135200   1303.40000000     1.79767440
#
#         openTime      closeTime    firstId     lastId  count
# 0  1697717990039  1697804390039  424080993  424130783  49791
# 1  1697717986994  1697804386994   93821788   93830439   8652
# 2  1697717985413  1697804385413  227890498  227928396  37899
# 3  1697717987133  1697804387133   45562175   45564043   1869
# 4  1697717974007  1697804374007    5404041    5404087     47
#
# [5 rows x 21 columns]
# CSV file created successfully.
